# %% [markdown]
# # Python Executor - Attempt #1
#
# **Stage:** execution_failed
# **Created:** 2025-09-03 11:19:37
#
# ## Error Context
#
# **Error:** Missing Module: 'framework' not available in Python environment
# 💡 SOLUTION: Add framework to your Python environment:
#    /opt/miniconda3/envs/bluesky/bin/python -m pip install framework
#
# **Full Traceback:**
# ```
# Traceback (most recent call last):
#   File "/Users/magarces/agenticAI_bolt-main/version-control/bolt-4/alpha_berkeley/interfaces/CLI/../../src/framework/services/python_executor/executor_node.py", line 467, in executor_node
#     execution_result = await executor.execute_code(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/magarces/agenticAI_bolt-main/version-control/bolt-4/alpha_berkeley/interfaces/CLI/../../src/framework/services/python_executor/executor_node.py", line 57, in execute_code
#     return await self._execute_with_subprocess(wrapped_code, execution_folder)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/magarces/agenticAI_bolt-main/version-control/bolt-4/alpha_berkeley/interfaces/CLI/../../src/framework/services/python_executor/executor_node.py", line 126, in _execute_with_subprocess
#     raise CodeRuntimeError(
# framework.services.python_executor.exceptions.CodeRuntimeError: Missing Module: 'framework' not available in Python environment
# 💡 SOLUTION: Add framework to your Python environment:
#    /opt/miniconda3/envs/bluesky/bin/python -m pip install framework
#
# ```
#
# **Execution Stage:** Code execution failed during wrapped code execution
#
# **Debug Information:**
# - Error Type: CodeRuntimeError
# - Error Message: Missing Module: 'framework' not available in Python environment
# 💡 SOLUTION: Add framework to your Python environment:
#    /opt/miniconda3/envs/bluesky/bin/python -m pip install framework
# - Generated Code Length: 681 characters

# %%
# Load execution context
from framework.context import load_context
context = load_context('../context.json')

# %%
from bluesky import plans as bp
from bluesky import RunEngine
from ophyd import Device, Component, Signal

def comprehensive_angle_scan():
    # Define results dictionary for tracking
    results = {}

    # Simple angular scan from 0 to 180 degrees
    def angular_scan(motor, start=0, stop=180, num_points=19):
        yield from bp.scan([motor], motor, start, stop, num_points)

    # Execute the scan
    RE = RunEngine({})
    motor = Signal(name='angle_motor')
    results['scan_data'] = RE(angular_scan(motor))

    return results

# Optional: Run the scan if script is executed directly
if __name__ == '__main__':
    results = comprehensive_angle_scan()
    print(results)
